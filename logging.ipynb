# %%
#Loggging is crucial method for any application to 
# track evebts errors and operational information

# %%
import logging

# Remove any existing handlers
for handler in logging.root.handlers[:]:
    logging.root.removeHandler(handler)

logging.basicConfig(
    filename="app.log",
    filemode="w",
    level=logging.DEBUG,
    format="%(asctime)s - %(name)s - %(levelname)s - %(message)s",
    datefmt="%Y-%m-%d %H:%M:%S",
    force=True   # Python 3.8+
)

logging.debug("Debug")
logging.info("Info")
logging.warning("Warning")
logging.error("Error")
logging.critical("Critical")

print("Done")
# Out:
# Done

# %%
#config logging
logging.basicConfig(

# %%
import logging

logger1 = logging.getLogger("module1")
logger1.setLevel(logging.DEBUG)

logger2 = logging.getLogger("module2")
logger2.setLevel(logging.WARNING)

logging.basicConfig(
    level=logging.DEBUG,
    format="%(asctime)s - %(name)s - %(levelname)s - %(message)s",
    force=True      # Important for Jupyter Notebook
)

logger1.debug("Debug message from module1")
logger1.info("Info message from module1")

logger2.debug("This will not be displayed")
logger2.warning("Warning message from module2")
# Out:
# 2026-07-30 20:58:18,096 - module1 - DEBUG - Debug message from module1
# 2026-07-30 20:58:18,097 - module1 - INFO - Info message from module1
# 2026-07-30 20:58:18,099 - module2 - WARNING - Warning message from module2
