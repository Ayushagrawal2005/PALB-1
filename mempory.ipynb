# %%
import sys

a=[]
print(sys.getrefcount(a))
# Out:
# 2

# %%
import gc
gc.enable()

# %%
gc.collect()
# Out:
# 33

# %%
print(gc.get_stats())
# Out:
# [{'collections': 74, 'collected': 1443, 'uncollectable': 0}, {'collections': 6, 'collected': 390, 'uncollectable': 0}, {'collections': 1, 'collected': 33, 'uncollectable': 0}]
